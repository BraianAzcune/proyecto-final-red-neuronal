# %% [markdown]
# ### Recursos utilizados
#
# https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
"""
Descargar CIFAR10 y convertir a tensores para que lo pueda utilizar Pytorch
"""
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     ])#transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

batch_size = 64

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)


classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
"""
Mostrar imagenes
"""
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


def print_random_image():
    # get some random training images
    dataiter = iter(trainloader)
    images, labels = next(dataiter)

    # show images
    imshow(torchvision.utils.make_grid(images))
    # print labels
    print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))

    # ver la primera imagen cruda
    print(images[0].shape)
    #valor mas grande y pequeño
    print("max value",torch.max(images[0]))
    print("min value",torch.min(images[0]))
    print(images[0])
# Out:
# frog  deer  car   car
# torch.Size([3, 32, 32])
# tensor([[[0.7255, 0.7333, 0.7333,  ..., 0.6980, 0.6980, 0.6941],
#          [0.7216, 0.7255, 0.7255,  ..., 0.6980, 0.6941, 0.6902],
#          [0.7216, 0.7255, 0.7216,  ..., 0.6980, 0.6941, 0.6902],
#          ...,
#          [0.5490, 0.4863, 0.3686,  ..., 0.4510, 0.5137, 0.5412],
#          [0.5529, 0.5098, 0.4471,  ..., 0.5961, 0.6039, 0.5490],
#          [0.5686, 0.5333, 0.5137,  ..., 0.5765, 0.5255, 0.5020]],
#
#         [[0.7529, 0.7529, 0.7569,  ..., 0.7255, 0.7255, 0.7216],
#          [0.7490, 0.7490, 0.7529,  ..., 0.7255, 0.7216, 0.7176],
#          [0.7451, 0.7451, 0.7490,  ..., 0.7255, 0.7216, 0.7176],
#          ...,
#          [0.5569, 0.4902, 0.3843,  ..., 0.5176, 0.5843, 0.6118],
#          [0.5529, 0.5137, 0.4471,  ..., 0.6471, 0.6627, 0.6078],
#          [0.5725, 0.5412, 0.4980,  ..., 0.6039, 0.5725, 0.5608]],
#
#         [[0.7843, 0.7843, 0.7804,  ..., 0.7569, 0.7569, 0.7529],
#          [0.7804, 0.7804, 0.7843,  ..., 0.7569, 0.7529, 0.7490],
#          [0.7765, 0.7804, 0.7804,  ..., 0.7569, 0.7529, 0.7490],
#          ...,
#          [0.5647, 0.4980, 0.4000,  ..., 0.5725, 0.5961, 0.6196],
#          [0.5490, 0.4980, 0.4549,  ..., 0.6000, 0.6196, 0.6078],
#          [0.5647, 0.5333, 0.4863,  ..., 0.6196, 0.6078, 0.6118]]])
# max value tensor(0.8196)
# min value tensor(0.0078)
